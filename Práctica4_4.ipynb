# %%
# Práctica 4.4 PIA - Álvaro García Rodrigo

# %%
# Ejercicio 1

# %%
import pandas as pd
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)
#df.head()
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
X= df.iloc[0:100, [0,2]].values

# %%
z = df.iloc[0:100, 4].values

# %%
import numpy as np
y = np.where(z == 'Iris-setosa', 0, 1)
print(type(y))
# Out:
# <class 'numpy.ndarray'>

# %%
# Ejercicio 2

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(2, input_shape=(2,), activation=tf.nn.relu),
                                    tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)])
# Out:
# 2023-03-18 14:42:21.709101: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-18 14:42:21.997881: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-18 14:42:21.997915: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
model.compile(#optimizer = 'adam',
              optimizer = 'sgd',
              #loss = 'mean_squared_error',
              #loss = 'sparse_categorical_crossentropy',
              loss = 'binary_crossentropy',
              metrics=['accuracy'])

model.fit(X,y, epochs=10)

model.evaluate(X, y)

classifications = model.predict(X)

print(classifications[0])
print(type(X))
print(type(y))
print(X.shape)
print(y.shape)
print(classifications.shape)
print(type(classifications))
# Out:
# Epoch 1/10
# 4/4 [==============================] - 1s 9ms/step - loss: 0.7731 - accuracy: 0.5000
# Epoch 2/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7455 - accuracy: 0.5000
# Epoch 3/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7323 - accuracy: 0.5000
# Epoch 4/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7229 - accuracy: 0.5000
# Epoch 5/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7105 - accuracy: 0.5000
# Epoch 6/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7006 - accuracy: 0.5000
# Epoch 7/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6974 - accuracy: 0.5000
# Epoch 8/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6963 - accuracy: 0.5000
# Epoch 9/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6961 - accuracy: 0.5000
# Epoch 10/10
# ...
# 4/4 [==============================] - 0s 10ms/step
# [0.4175656]
# ...

# %%
# Ejercicio 3

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(2, input_shape=(2,), activation=tf.nn.relu),
                                    tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)])
model.compile(#optimizer = 'adam',
              optimizer = 'sgd',
              loss = 'binary_crossentropy',
              #loss = 'mean_squared_error',
              metrics=['accuracy'])

print(model.evaluate(X, y))

classifications = model.predict(X)

print(classifications[0])
# Out:
# 4/4 [==============================] - 1s 5ms/step - loss: 0.6874 - accuracy: 0.5000
# [0.6873770952224731, 0.5]
# 4/4 [==============================] - 0s 4ms/step
# [0.5832791]

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 2)                 6
#
#  dense_3 (Dense)             (None, 1)                 3
#
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Ejercicio 4

# %%
print(model.fit(X,y, epochs=10))
# Out:
# Epoch 1/10
# 4/4 [==============================] - 1s 6ms/step - loss: 0.6881 - accuracy: 0.5000
# Epoch 2/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6910 - accuracy: 0.5000
# Epoch 3/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6912 - accuracy: 0.5000
# Epoch 4/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6862 - accuracy: 0.5000
# Epoch 5/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6853 - accuracy: 0.5000
# Epoch 6/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6869 - accuracy: 0.5000
# Epoch 7/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6858 - accuracy: 0.5000
# Epoch 8/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6839 - accuracy: 0.5000
# Epoch 9/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6841 - accuracy: 0.5000
# Epoch 10/10
# ...

# %%
print(model.fit(X,y, epochs=100))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6831 - accuracy: 0.5000
# Epoch 2/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6833 - accuracy: 0.5000
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6857 - accuracy: 0.5000
# Epoch 4/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6846 - accuracy: 0.5000
# Epoch 5/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6832 - accuracy: 0.5000
# Epoch 6/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6821 - accuracy: 0.5000
# Epoch 7/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6832 - accuracy: 0.5000
# Epoch 8/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6826 - accuracy: 0.5000
# Epoch 9/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6837 - accuracy: 0.5000
# Epoch 10/100
# ...

# %%
print(model.fit(X,y, epochs=1000))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6572 - accuracy: 0.5000
# Epoch 2/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6567 - accuracy: 0.5000
# Epoch 3/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6573 - accuracy: 0.5000
# Epoch 4/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6568 - accuracy: 0.5000
# Epoch 5/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6558 - accuracy: 0.5000
# Epoch 6/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6561 - accuracy: 0.5000
# Epoch 7/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6557 - accuracy: 0.5000
# Epoch 8/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6557 - accuracy: 0.5000
# Epoch 9/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6541 - accuracy: 0.5000
# Epoch 10/1000
# ...

# %%
# Ejercicio 5

# %%
import tensorflow as tf

y=np.array(list(map(lambda x:0 if x=='Iris-setosa' else 1,z)))
print(type(y))

model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(2, input_shape=(2,), activation=tf.nn.relu),
                                    tf.keras.layers.Dense(2, activation=tf.nn.softmax)])

model.compile(#optimizer = 'adam',
              optimizer = 'sgd',
              loss = 'binary_crossentropy',
              #loss = 'mean_squared_error',
              metrics='accuracy')
# Out:
# <class 'numpy.ndarray'>

# %%
# Ejercicio 6

# %%
print(model.fit(X, y, epochs=100))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 9ms/step - loss: 3.0957 - accuracy: 0.5000
# Epoch 2/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9969 - accuracy: 0.5000
# Epoch 3/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.2478 - accuracy: 0.5000
# Epoch 4/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8696 - accuracy: 0.5000
# Epoch 5/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7382 - accuracy: 0.5000
# Epoch 6/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7058 - accuracy: 0.5000
# Epoch 7/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6984 - accuracy: 0.7000
# Epoch 8/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6966 - accuracy: 0.9300
# Epoch 9/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6961 - accuracy: 1.0000
# Epoch 10/100
# ...

# %%
# Ejercicio 7

# %%
import tensorflow as tf

df=df.sample(frac=1)
X= df.iloc[0:100, [0,2]].values
z = df.iloc[0:100, 4].values
y=np.array(list(map(lambda x:0 if x=='Iris-setosa' else 1,z)))

model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(2, input_shape=(2,), activation=tf.nn.relu),
                                    tf.keras.layers.Dense(2, activation=tf.nn.softmax)])

model.compile(#optimizer = 'adam',
              optimizer = 'sgd',
              loss = 'binary_crossentropy',
              #loss = 'mean_squared_error',
              metrics='accuracy')

print(model.fit(X, y, epochs=100))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 7ms/step - loss: 0.7015 - accuracy: 0.3400
# Epoch 2/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7007 - accuracy: 0.3500
# Epoch 3/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7000 - accuracy: 0.3500
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6993 - accuracy: 0.3500
# Epoch 5/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6987 - accuracy: 0.3500
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6983 - accuracy: 0.3500
# Epoch 7/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6978 - accuracy: 0.3500
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6973 - accuracy: 0.4200
# Epoch 9/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6969 - accuracy: 0.4400
# Epoch 10/100
# ...

# %%
# Ejercicio 8

# %%
print(model.fit(X, y, epochs=10))
# Out:
# Epoch 1/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 2/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 3/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 4/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 5/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 6/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 7/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 8/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 9/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 10/10
# ...

# %%
print(model.fit(X, y, epochs=100))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 8/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 9/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 1.0000
# Epoch 10/100
# ...

# %%
print(model.fit(X, y, epochs=1000))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 1.0000
# Epoch 2/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 1.0000
# Epoch 3/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 1.0000
# Epoch 4/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6932 - accuracy: 1.0000
# Epoch 5/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6932 - accuracy: 1.0000
# Epoch 6/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 1.0000
# Epoch 7/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 1.0000
# Epoch 8/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 1.0000
# Epoch 9/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 1.0000
# Epoch 10/1000
# ...

# %%
# Ejercicio 9

# %%
import tensorflow as tf

df=df.sample(frac=1)
X= df.iloc[0:100, [0,2]].values
z = df.iloc[0:100, 4].values
y=np.array(list(map(lambda x:0 if x=='Iris-setosa' else 1,z)))
X_std = np.copy(X)
X_std[:, 0] = (X[:, 0] - X[:, 0].mean()) / X[:, 0].std()
X_std[:, 1] = (X[:, 1] - X[:, 1].mean()) / X[:, 1].std()

model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(2, input_shape=(2,), activation=tf.nn.relu),
                                    tf.keras.layers.Dense(2, activation=tf.nn.softmax)])

model.compile(#optimizer = 'adam',
              optimizer = 'sgd',
              loss = 'binary_crossentropy',
              #loss = 'mean_squared_error',
              metrics='accuracy')

print(model.fit(X_std, y, epochs=100))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 7ms/step - loss: 0.7371 - accuracy: 0.9100
# Epoch 2/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7340 - accuracy: 0.9100
# Epoch 3/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7316 - accuracy: 0.9100
# Epoch 4/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7293 - accuracy: 0.9000
# Epoch 5/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7270 - accuracy: 0.9000
# Epoch 6/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7248 - accuracy: 0.9000
# Epoch 7/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7229 - accuracy: 0.8700
# Epoch 8/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7215 - accuracy: 0.8600
# Epoch 9/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7200 - accuracy: 0.8400
# Epoch 10/100
# ...

# %%
# Ejercicio 10

# %%
y=df.iloc[0:,4].values
X=df.iloc[0:,0:4].values
X_std = np.copy(X)
X_std[:, 0] = (X[:, 0] - X[:, 0].mean()) / X[:, 0].std()
X_std[:, 1] = (X[:, 1] - X[:, 1].mean()) / X[:, 1].std()
X_std[:, 2] = (X[:, 2] - X[:, 2].mean()) / X[:, 2].std()
X_std[:, 3] = (X[:, 3] - X[:, 3].mean()) / X[:, 3].std()
y=np.array(list(map(lambda x:[1,0,0] if x=='Iris-setosa' else [0,1,0] if x=='Iris-versicolor' else [0,0,1],y)))
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(4, input_shape=(4,), activation=tf.nn.relu),
                                    tf.keras.layers.Dense(3, activation=tf.nn.softmax)])

model.compile(optimizer = 'adam',
              #loss = 'binary_crossentropy',
              loss = 'categorical_crossentropy',
              metrics='accuracy')

print(model.fit(X_std, y, epochs=100))
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 7ms/step - loss: 1.0783 - accuracy: 0.3267
# Epoch 2/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0619 - accuracy: 0.3267
# Epoch 3/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0468 - accuracy: 0.3400
# Epoch 4/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0317 - accuracy: 0.3400
# Epoch 5/100
# 5/5 [==============================] - 0s 10ms/step - loss: 1.0177 - accuracy: 0.3467
# Epoch 6/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0039 - accuracy: 0.3467
# Epoch 7/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.9906 - accuracy: 0.3533
# Epoch 8/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9780 - accuracy: 0.3533
# Epoch 9/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9659 - accuracy: 0.3600
# Epoch 10/100
# ...

# %%
# Ejercicio 11

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(4, input_shape=(4,), activation=tf.nn.relu),
                                    tf.keras.layers.Dense(16, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(3, activation=tf.nn.softmax)])

model.compile(optimizer = 'adam',
              #loss = 'binary_crossentropy',
              loss = 'categorical_crossentropy',
              metrics='accuracy')

print(model.fit(X_std, y, epochs=100))
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 6ms/step - loss: 1.2257 - accuracy: 0.3333
# Epoch 2/100
# 5/5 [==============================] - 0s 6ms/step - loss: 1.1907 - accuracy: 0.3333
# Epoch 3/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1615 - accuracy: 0.3333
# Epoch 4/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.1326 - accuracy: 0.3333
# Epoch 5/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1055 - accuracy: 0.3333
# Epoch 6/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0800 - accuracy: 0.3333
# Epoch 7/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0557 - accuracy: 0.3267
# Epoch 8/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0339 - accuracy: 0.3200
# Epoch 9/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0117 - accuracy: 0.4000
# Epoch 10/100
# ...

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(2, input_shape=(4,), activation=tf.nn.relu),
                                    tf.keras.layers.Dense(16, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(3, activation=tf.nn.softmax)])

model.compile(optimizer = 'adam',
              #loss = 'binary_crossentropy',
              loss = 'categorical_crossentropy',
              metrics='accuracy')

print(model.fit(X_std, y, epochs=1000))
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 1s 5ms/step - loss: 1.4311 - accuracy: 0.0133
# Epoch 2/1000
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3950 - accuracy: 0.0400
# Epoch 3/1000
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3596 - accuracy: 0.0333
# Epoch 4/1000
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3299 - accuracy: 0.0200
# Epoch 5/1000
# 5/5 [==============================] - 0s 7ms/step - loss: 1.2987 - accuracy: 0.0000e+00
# Epoch 6/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 1.2708 - accuracy: 0.0133
# Epoch 7/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 1.2444 - accuracy: 0.0067
# Epoch 8/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 1.2198 - accuracy: 0.0133
# Epoch 9/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 1.1965 - accuracy: 0.0133
# Epoch 10/1000
# ...

# %%
model.compile(optimizer = 'sgd',
              loss = 'binary_crossentropy',
              #loss = 'categorical_crossentropy',
              metrics='accuracy')

print(model.fit(X_std, y, epochs=1000))
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 1s 6ms/step - loss: 1.5247 - accuracy: 0.5400
# Epoch 2/1000
# 5/5 [==============================] - 0s 6ms/step - loss: 0.9527 - accuracy: 0.6467
# Epoch 3/1000
# 5/5 [==============================] - 0s 6ms/step - loss: 0.5933 - accuracy: 0.7133
# Epoch 4/1000
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4016 - accuracy: 0.7800
# Epoch 5/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3040 - accuracy: 0.8600
# Epoch 6/1000
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2503 - accuracy: 0.9000
# Epoch 7/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2177 - accuracy: 0.9267
# Epoch 8/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1962 - accuracy: 0.9467
# Epoch 9/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1809 - accuracy: 0.9533
# Epoch 10/1000
# ...

# %%
# Ejercicio 12

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.1,random_state=0)

# %%
# Ejercico 13

# %%
print(model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=1000))
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 0s 116ms/step - loss: 2.4313 - accuracy: 0.3556 - val_loss: 2.8976 - val_accuracy: 0.1333
# Epoch 2/1000
# 5/5 [==============================] - 0s 33ms/step - loss: 1.8179 - accuracy: 0.3556 - val_loss: 1.2923 - val_accuracy: 0.2667
# Epoch 3/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 1.0874 - accuracy: 0.5704 - val_loss: 0.9851 - val_accuracy: 0.6667
# Epoch 4/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5562 - accuracy: 0.7630 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 5/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0598 - accuracy: 0.9556 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 6/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0455 - accuracy: 0.9852 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 7/1000
# ...

# %%
print(model.evaluate(X_train, y_train))
print(model.evaluate(X_test, y_test))
# Out:
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1036 - accuracy: 0.9556
# [0.10363118350505829, 0.9555555582046509]
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0028 - accuracy: 1.0000
# [0.0027668240945786238, 1.0]

# %%
print(model.predict(X_train[0:2]))
# Out:
# 1/1 [==============================] - 0s 94ms/step
# [[1.4279041e-03 9.9852532e-01 4.6818328e-05]
#  [8.1196713e-04 9.9817538e-01 1.0125613e-03]]

# %%
print(X_train[0:2])
# Out:
# [[5.5 2.4 3.7 1. ]
#  [5.  2.  3.5 1. ]]

# %%
prediccion = np.array([[7.9, 3.8, 6.4, 2.0]])
print(np.array(prediccion))
# Out:
# [[7.9 3.8 6.4 2. ]]

# %%
print(model.predict(prediccion))
# Out:
# 1/1 [==============================] - 0s 32ms/step
# [[4.9222608e-06 1.7133828e-02 9.8286128e-01]]

# %%
print(X_train[50:52])
# Out:
# [[5.5 2.5 4.  1.3]
#  [4.6 3.6 1.  0.2]]

# %%
prediccion = X_train[75:76]
print(prediccion)
# Out:
# [[5.7 2.6 3.5 1. ]]

# %%
print(model.predict(prediccion))
# Out:
# 1/1 [==============================] - 0s 32ms/step
# [[6.6411505e-03 9.9335796e-01 8.7414736e-07]]

# %%
prediccion = X_train[125:126]
print(prediccion)
# Out:
# [[5.7 2.5 5.  2. ]]

# %%
print(model.predict(prediccion))
# Out:
# 1/1 [==============================] - 0s 35ms/step
# [[4.9222608e-06 1.7133828e-02 9.8286128e-01]]
